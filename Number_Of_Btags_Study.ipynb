# %%
from Generic import *

# %%
Version="/home/jruizalv/V1/"

#Cuts
HTCut = ROOT.TCut("THT>550")
J1PTCut = ROOT.TCut("jet1_pt>150")
L3 = ROOT.TCut("Number_CSVLbtagged_jets>=3")
M3 = ROOT.TCut("Number_CSVMbtagged_jets>=3")
M2L1 = ROOT.TCut("Number_CSVMbtagged_jets>=2 && Number_CSVLbtagged_jets>=1")
M1L2 = ROOT.TCut("Number_CSVMbtagged_jets>=1 && Number_CSVLbtagged_jets>=2")
M2T1 = ROOT.TCut("Number_CSVMbtagged_jets>=2 && Number_CSVTbtagged_jets>=1")
M1T2 = ROOT.TCut("Number_CSVMbtagged_jets>=1 && Number_CSVTbtagged_jets>=2")
T3 = ROOT.TCut("Number_CSVTbtagged_jets>=3")
T2L1 = ROOT.TCut("Number_CSVTbtagged_jets>=2 && Number_CSVLbtagged_jets>=1")
T1L2 = ROOT.TCut("Number_CSVTbtagged_jets>=1 && Number_CSVLbtagged_jets>=2")
T1M1L1 = ROOT.TCut("Number_CSVTbtagged_jets>=1 && Number_CSVMbtagged_jets>=1 && Number_CSVLbtagged_jets>=1")

AllSamples=[]
TotalEntries=[]

for f in files:
    CutsChain=ROOT.TChain("cuts")
    CutsChain.Add(Version+f)
    entries = CutsChain.GetEntries()
    if files.index(f)>=0 and files.index(f)<=NsignalFiles-1: print "Filling signal..."
    elif files.index(f)>0: print "Filling bkgs..."
    print "Entries for file ", f, " are: ", entries
    TempTree= ROOT.TNtuple(ListTreesNamesA[files.index(f)],ListTreesNamesA[files.index(f)],TreeStructure)
    TC=0; L3C=0; M3C=0; M2L1C=0; M1L2C=0; M2T1C=0; M1T2C=0; T3C=0; T2L1C=0; T1L2C=0; T1M1L1C=0
    for i in xrange(entries):
        CutsChain.GetEntry(i)
        if CutsChain.THT<600: continue
        if CutsChain.jet1_pt<150: continue
        TC+=1
        if (CutsChain.Number_CSVLbtagged_jets>=3): L3C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=3): M3C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=2 and CutsChain.Number_CSVLbtagged_jets>=1): M2L1C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=1 and CutsChain.Number_CSVLbtagged_jets>=2): M1L2C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=2 and CutsChain.Number_CSVTbtagged_jets>=1): M2T1C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=1 and CutsChain.Number_CSVTbtagged_jets>=2): M1T2C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=3): T3C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=2 and CutsChain.Number_CSVLbtagged_jets>=1): T2L1C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=1 and CutsChain.Number_CSVLbtagged_jets>=2): T1L2C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=1 and CutsChain.Number_CSVMbtagged_jets>=1 and CutsChain.Number_CSVLbtagged_jets>=1): T1M1L1C+=1
    TotalEntries.append(TC)
    AllSamples.append([L3C, M3C, M2L1C, M1L2C, M2T1C, M1T2C, T3C, T2L1C, T1L2C, T1M1L1C])
# Out:
# Filling signal...
# Entries for file  TpJetM600_5318_Full_analyzed.root  are:  95167
# Filling signal...
# Entries for file  TpJetM650_5318_Full_analyzed.root  are:  98817
# Filling signal...
# Entries for file  TpJetM700_5318_Full_analyzed.root  are:  99464
# Filling signal...
# Entries for file  TpJetM750_5318_Full_analyzed.root  are:  99375
# Filling signal...
# Entries for file  TpJetM800_5318_Full_analyzed.root  are:  95801
# Filling signal...
# Entries for file  TpJetM850_5318_Full_analyzed.root  are:  99257
# Filling signal...
# Entries for file  TpJetM900_5318_Full_analyzed.root  are:  99174
# Filling signal...
# Entries for file  TpJetM950_5318_Full_analyzed.root  are:  95960
# Filling signal...
# Entries for file  TpJetM1000_5318_Full_analyzed.root  are:  99078
# Filling bkgs...
# Entries for file  TTJetsF_5318_Full_analyzed.root  are:  61941200
# Filling bkgs...
# Entries for file  QCD_HT_500_1000_5318_Full_analyzed.root  are:  29019521
# Filling bkgs...
# Entries for file  QCD_HT_1000_Inf_5318_Full_analyzed.root  are:  13438527

# %%
print TotalEntries
print AllSamples
# Out:
# [10338, 13617, 16475, 18342, 18823, 20056, 20749, 19698, 19350, 1703495, 1096884, 1646920]
# [[7041, 3306, 7324, 9310, 6767, 4315, 1061, 4315, 8108, 8414], [9329, 4286, 9742, 12235, 8980, 5577, 1301, 5577, 10622, 11071], [11357, 5276, 11772, 14877, 10776, 6571, 1589, 6571, 12807, 13323], [12577, 5783, 13053, 16607, 11875, 7190, 1626, 7190, 14143, 14694], [12749, 5810, 13522, 17010, 12283, 7319, 1505, 7319, 14552, 15139], [13501, 6171, 14019, 17974, 12684, 7453, 1602, 7453, 15225, 15882], [13725, 6101, 14446, 18483, 13008, 7418, 1510, 7418, 15590, 16286], [13097, 5634, 13541, 17533, 12187, 6890, 1341, 6890, 14632, 15311], [12608, 5333, 12931, 17043, 11545, 6455, 1225, 6455, 14127, 14841], [812577, 164162, 821689, 1317838, 730647, 373139, 25382, 373139, 1061994, 1188420], [107986, 6804, 57135, 177276, 44402, 20384, 1232, 20384, 91890, 126078], [170303, 11351, 89348, 285559, 65763, 26569, 1699, 26569, 140230, 194471]]

# %%
#Saving results
FullArray=np.array([TotalEntries, AllSamples])
np.save("3bs_study",FullArray)

# %%
#Reuslts from HT>600, PT(j1)>150
#TotalEntries=[10338, 13617, 16475, 18342, 18823, 20056, 20749, 19698, 19350, 1703495, 1096884, 1646920]
#AllSamples=[[7041, 3306, 7324, 9310, 6767, 4315, 1061, 4315, 8108, 8414], [9329, 4286, 9742, 12235, 8980, 5577, 1301, 5577, 10622, 11071], [11357, 5276, 11772, 14877, 10776, 6571, 1589, 6571, 12807, 13323], [12577, 5783, 13053, 16607, 11875, 7190, 1626, 7190, 14143, 14694], [12749, 5810, 13522, 17010, 12283, 7319, 1505, 7319, 14552, 15139], [13501, 6171, 14019, 17974, 12684, 7453, 1602, 7453, 15225, 15882], [13725, 6101, 14446, 18483, 13008, 7418, 1510, 7418, 15590, 16286], [13097, 5634, 13541, 17533, 12187, 6890, 1341, 6890, 14632, 15311], [12608, 5333, 12931, 17043, 11545, 6455, 1225, 6455, 14127, 14841], [812577, 164162, 821689, 1317838, 730647, 373139, 25382, 373139, 1061994, 1188420], [107986, 6804, 57135, 177276, 44402, 20384, 1232, 20384, 91890, 126078], [170303, 11351, 89348, 285559, 65763, 26569, 1699, 26569, 140230, 194471]]
Cuts=["L3", "M3", "M2L1", "M1L2", "M2T1", "M1T2", "T3", "T2L1", "T1L2", "T1M1L1"]

print "Efficiencies for different 3b's tags selection, HT>600, PT(j1)>150"
print "--------------------------------------"
for i in xrange(len(TotalEntries)):
    print "For", ListTreesNamesA[i].split('n')[0]
    for j in xrange(len(AllSamples[i])):
        print Cuts[j]+":", "{0:.2f}+-{1:.2e}".format(float(AllSamples[i][j])/TotalEntries[i],
                                                     DivE(float(AllSamples[i][j]),TotalEntries[i],np.sqrt(AllSamples[i][j]),np.sqrt(TotalEntries[i])))
    print "--------------------------------------"
print "--------------------------------------"
print "--------------------------------------"

print "S/B -----------------------------------"
for i in xrange(len(TotalEntries[:NsignalFiles])):
    print "For", ListTreesNamesA[i].split('n')[0]
    for j in xrange(len(AllSamples[i])):
        S=float(AllSamples[i][j]*NWeights[i]); ES=NWeights[i]*np.sqrt(AllSamples[i][j])
        B=((AllSamples[NsignalFiles][j]*TWeight)+(AllSamples[NsignalFiles+1][j]*Q500Weight)+(AllSamples[NsignalFiles+2][j]*Q1000Weight))
        EB=(np.sqrt(AllSamples[NsignalFiles][j])*TWeight)+(np.sqrt(AllSamples[NsignalFiles+1][j])*Q500Weight)+(np.sqrt(AllSamples[NsignalFiles+2][j])*Q1000Weight)
        print Cuts[j]+":", "{0:.2e}+-{1:.2e}".format(S/B,DivE(S,B,ES,EB))
    print "--------------------------------------"
print "--------------------------------------"
print "--------------------------------------"

print "S/sqrt(S+B)---------------------------"
for i in xrange(len(TotalEntries[:NsignalFiles])):
    print "For", ListTreesNamesA[i].split('n')[0]
    for j in xrange(len(AllSamples[i])):
        S=float(AllSamples[i][j]*NWeights[i]); ES=NWeights[i]*np.sqrt(AllSamples[i][j])
        B=((AllSamples[NsignalFiles][j]*TWeight)+(AllSamples[NsignalFiles+1][j]*Q500Weight)+(AllSamples[NsignalFiles+2][j]*Q1000Weight))
        EB=(np.sqrt(AllSamples[NsignalFiles][j])*TWeight)+(np.sqrt(AllSamples[NsignalFiles+1][j])*Q500Weight)+(np.sqrt(AllSamples[NsignalFiles+2][j])*Q1000Weight)
        print Cuts[j]+":", "{0:.2e}+-{1:.2e}".format(S/np.sqrt(S+B),
                                                     DivE(S,np.sqrt(S+B),ES,SqrtE(S+B,ES+EB)))
    print "--------------------------------------"
# Out:
# Efficiencies for different 3b's tags selection, HT>600, PT(j1)>150
# --------------------------------------
# For S600
# L3: 0.68+-1.48e-02
# M3: 0.32+-8.71e-03
# M2L1: 0.71+-1.52e-02
# M1L2: 0.90+-1.82e-02
# M2T1: 0.65+-1.44e-02
# M1T2: 0.42+-1.05e-02
# T3: 0.10+-4.16e-03
# T2L1: 0.42+-1.05e-02
# T1L2: 0.78+-1.64e-02
# T1M1L1: 0.81+-1.69e-02
# --------------------------------------
# For S650
# L3: 0.69+-1.30e-02
# M3: 0.31+-7.51e-03
# M2L1: 0.72+-1.34e-02
# M1L2: 0.90+-1.58e-02
# M2T1: 0.66+-1.26e-02
# M1T2: 0.41+-8.99e-03
# T3: 0.10+-3.47e-03
# T2L1: 0.41+-8.99e-03
# T1L2: 0.78+-1.43e-02
# T1M1L1: 0.81+-1.47e-02
# --------------------------------------
# For S700
# L3: 0.69+-1.18e-02
# M3: 0.32+-6.90e-03
# M2L1: 0.71+-1.22e-02
# M1L2: 0.90+-1.44e-02
# M2T1: 0.65+-1.14e-02
# M1T2: 0.40+-8.03e-03
# T3: 0.10+-3.17e-03
# T2L1: 0.40+-8.03e-03
# T1L2: 0.78+-1.29e-02
# T1M1L1: 0.81+-1.33e-02
# --------------------------------------
# For S750
# L3: 0.69+-1.12e-02
# M3: 0.32+-6.47e-03
# M2L1: 0.71+-1.15e-02
# M1L2: 0.91+-1.37e-02
# M2T1: 0.65+-1.07e-02
# M1T2: 0.39+-7.52e-03
# T3: 0.09+-2.85e-03
# T2L1: 0.39+-7.52e-03
# T1L2: 0.77+-1.22e-02
# T1M1L1: 0.80+-1.25e-02
# --------------------------------------
# For S800
# L3: 0.68+-1.09e-02
# M3: 0.31+-6.30e-03
# M2L1: 0.72+-1.14e-02
# M1L2: 0.90+-1.35e-02
# M2T1: 0.65+-1.06e-02
# M1T2: 0.39+-7.38e-03
# T3: 0.08+-2.64e-03
# T2L1: 0.39+-7.38e-03
# T1L2: 0.77+-1.20e-02
# T1M1L1: 0.80+-1.24e-02
# --------------------------------------
# For S850
# L3: 0.67+-1.05e-02
# M3: 0.31+-6.09e-03
# M2L1: 0.70+-1.08e-02
# M1L2: 0.90+-1.30e-02
# M2T1: 0.63+-1.01e-02
# M1T2: 0.37+-6.93e-03
# T3: 0.08+-2.56e-03
# T2L1: 0.37+-6.93e-03
# T1L2: 0.76+-1.15e-02
# T1M1L1: 0.79+-1.19e-02
# --------------------------------------
# For S900
# L3: 0.66+-1.02e-02
# M3: 0.29+-5.81e-03
# M2L1: 0.70+-1.06e-02
# M1L2: 0.89+-1.27e-02
# M2T1: 0.63+-9.85e-03
# M1T2: 0.36+-6.63e-03
# T3: 0.07+-2.38e-03
# T2L1: 0.36+-6.63e-03
# T1L2: 0.75+-1.12e-02
# T1M1L1: 0.78+-1.16e-02
# --------------------------------------
# For S950
# L3: 0.66+-1.05e-02
# M3: 0.29+-5.85e-03
# M2L1: 0.69+-1.08e-02
# M1L2: 0.89+-1.31e-02
# M2T1: 0.62+-1.00e-02
# M1T2: 0.35+-6.71e-03
# T3: 0.07+-2.34e-03
# T2L1: 0.35+-6.71e-03
# T1L2: 0.74+-1.14e-02
# T1M1L1: 0.78+-1.18e-02
# --------------------------------------
# For S1000
# L3: 0.65+-1.05e-02
# M3: 0.28+-5.76e-03
# M2L1: 0.67+-1.07e-02
# M1L2: 0.88+-1.31e-02
# M2T1: 0.60+-9.84e-03
# M1T2: 0.33+-6.55e-03
# T3: 0.06+-2.26e-03
# T2L1: 0.33+-6.55e-03
# T1L2: 0.73+-1.14e-02
# T1M1L1: 0.77+-1.18e-02
# --------------------------------------
# For T
# L3: 0.48+-8.95e-04
# M3: 0.10+-3.12e-04
# M2L1: 0.48+-9.02e-04
# M1L2: 0.77+-1.27e-03
# M2T1: 0.43+-8.30e-04
# M1T2: 0.22+-5.26e-04
# T3: 0.01+-1.05e-04
# T2L1: 0.22+-5.26e-04
# T1L2: 0.62+-1.08e-03
# T1M1L1: 0.70+-1.17e-03
# --------------------------------------
# For Q500
# L3: 0.10+-3.94e-04
# M3: 0.01+-8.11e-05
# M2L1: 0.05+-2.68e-04
# M1L2: 0.16+-5.38e-04
# M2T1: 0.04+-2.31e-04
# M1T2: 0.02+-1.48e-04
# T3: 0.00+-3.31e-05
# T2L1: 0.02+-1.48e-04
# T1L2: 0.08+-3.56e-04
# T1M1L1: 0.11+-4.33e-04
# --------------------------------------
# For Q1000
# L3: 0.10+-3.31e-04
# M3: 0.01+-7.01e-05
# M2L1: 0.05+-2.24e-04
# M1L2: 0.17+-4.60e-04
# M2T1: 0.04+-1.87e-04
# M1T2: 0.02+-1.12e-04
# T3: 0.00+-2.58e-05
# T2L1: 0.02+-1.12e-04
# T1L2: 0.09+-2.94e-04
# T1M1L1: 0.12+-3.60e-04
# --------------------------------------
# --------------------------------------
# --------------------------------------
# S/B -----------------------------------
# For S600
# L3: 2.63e-04+-3.88e-06
# M3: 1.64e-03+-4.44e-05
# M2L1: 4.79e-04+-7.35e-06
# M1L2: 2.12e-04+-2.66e-06
# M2T1: 5.59e-04+-9.08e-06
# M1T2: 7.67e-04+-1.62e-05
# T3: 3.04e-03+-1.65e-04
# T2L1: 7.67e-04+-1.62e-05
# T1L2: 3.41e-04+-4.79e-06
# T1M1L1: 2.64e-04+-3.56e-06
# --------------------------------------
# For S650
# L3: 2.77e-04+-3.65e-06
# M3: 1.69e-03+-4.21e-05
# M2L1: 5.07e-04+-6.99e-06
# M1L2: 2.21e-04+-2.49e-06
# M2T1: 5.90e-04+-8.63e-06
# M1T2: 7.88e-04+-1.52e-05
# T3: 2.96e-03+-1.52e-04
# T2L1: 7.88e-04+-1.52e-05
# T1L2: 3.55e-04+-4.49e-06
# T1M1L1: 2.76e-04+-3.33e-06
# --------------------------------------
# For S700
# L3: 2.71e-04+-3.31e-06
# M3: 1.67e-03+-3.91e-05
# M2L1: 4.92e-04+-6.33e-06
# M1L2: 2.16e-04+-2.25e-06
# M2T1: 5.68e-04+-7.79e-06
# M1T2: 7.46e-04+-1.36e-05
# T3: 2.91e-03+-1.41e-04
# T2L1: 7.46e-04+-1.36e-05
# T1L2: 3.44e-04+-4.05e-06
# T1M1L1: 2.67e-04+-3.00e-06
# --------------------------------------
# For S750
# L3: 2.48e-04+-2.91e-06
# M3: 1.51e-03+-3.45e-05
# M2L1: 4.50e-04+-5.59e-06
# M1L2: 1.99e-04+-1.99e-06
# M2T1: 5.17e-04+-6.86e-06
# M1T2: 6.74e-04+-1.19e-05
# T3: 2.46e-03+-1.19e-04
# T2L1: 6.74e-04+-1.19e-05
# T1L2: 3.13e-04+-3.56e-06
# T1M1L1: 2.43e-04+-2.63e-06
# --------------------------------------
# For S800
# L3: 2.20e-04+-2.57e-06
# M3: 1.33e-03+-3.03e-05
# M2L1: 4.08e-04+-5.00e-06
# M1L2: 1.78e-04+-1.76e-06
# M2T1: 4.68e-04+-6.13e-06
# M1T2: 6.00e-04+-1.06e-05
# T3: 1.99e-03+-9.82e-05
# T2L1: 6.00e-04+-1.06e-05
# T1L2: 2.82e-04+-3.17e-06
# T1M1L1: 2.19e-04+-2.34e-06
# --------------------------------------
# For S850
# L3: 1.89e-04+-2.16e-06
# M3: 1.15e-03+-2.57e-05
# M2L1: 3.44e-04+-4.16e-06
# M1L2: 1.53e-04+-1.48e-06
# M2T1: 3.93e-04+-5.09e-06
# M1T2: 4.97e-04+-8.71e-06
# T3: 1.72e-03+-8.37e-05
# T2L1: 4.97e-04+-8.71e-06
# T1L2: 2.40e-04+-2.66e-06
# T1M1L1: 1.87e-04+-1.96e-06
# --------------------------------------
# For S900
# L3: 1.66e-04+-1.89e-06
# M3: 9.78e-04+-2.20e-05
# M2L1: 3.06e-04+-3.66e-06
# M1L2: 1.36e-04+-1.30e-06
# M2T1: 3.48e-04+-4.46e-06
# M1T2: 4.27e-04+-7.48e-06
# T3: 1.40e-03+-6.90e-05
# T2L1: 4.27e-04+-7.48e-06
# T1L2: 2.12e-04+-2.32e-06
# T1M1L1: 1.65e-04+-1.72e-06
# --------------------------------------
# For S950
# L3: 1.41e-04+-1.63e-06
# M3: 8.04e-04+-1.85e-05
# M2L1: 2.55e-04+-3.13e-06
# M1L2: 1.15e-04+-1.12e-06
# M2T1: 2.90e-04+-3.81e-06
# M1T2: 3.53e-04+-6.35e-06
# T3: 1.11e-03+-5.64e-05
# T2L1: 3.53e-04+-6.35e-06
# T1L2: 1.77e-04+-1.99e-06
# T1M1L1: 1.38e-04+-1.47e-06
# --------------------------------------
# For S1000
# L3: 1.13e-04+-1.33e-06
# M3: 6.35e-04+-1.49e-05
# M2L1: 2.03e-04+-2.53e-06
# M1L2: 9.32e-05+-9.20e-07
# M2T1: 2.29e-04+-3.07e-06
# M1T2: 2.76e-04+-5.07e-06
# T3: 8.43e-04+-4.40e-05
# T2L1: 2.76e-04+-5.07e-06
# T1L2: 1.43e-04+-1.62e-06
# T1M1L1: 1.12e-04+-1.21e-06
# --------------------------------------
# --------------------------------------
# --------------------------------------
# S/sqrt(S+B)---------------------------
# For S600
# L3: 2.25e-01+-3.00e-03
# M3: 3.85e-01+-8.56e-03
# M2L1: 3.10e-01+-4.19e-03
# M1L2: 2.32e-01+-2.66e-03
# M2T1: 3.22e-01+-4.57e-03
# M1T2: 3.01e-01+-5.47e-03
# T3: 2.97e-01+-1.26e-02
# T2L1: 3.01e-01+-5.47e-03
# T1L2: 2.75e-01+-3.46e-03
# T1M1L1: 2.46e-01+-3.00e-03
# --------------------------------------
# For S650
# L3: 2.37e-01+-2.79e-03
# M3: 3.96e-01+-7.98e-03
# M2L1: 3.28e-01+-3.92e-03
# M1L2: 2.43e-01+-2.46e-03
# M2T1: 3.39e-01+-4.27e-03
# M1T2: 3.09e-01+-5.06e-03
# T3: 2.89e-01+-1.14e-02
# T2L1: 3.09e-01+-5.06e-03
# T1L2: 2.86e-01+-3.20e-03
# T1M1L1: 2.58e-01+-2.78e-03
# --------------------------------------
# For S700
# L3: 2.32e-01+-2.50e-03
# M3: 3.92e-01+-7.29e-03
# M2L1: 3.18e-01+-3.51e-03
# M1L2: 2.37e-01+-2.20e-03
# M2T1: 3.27e-01+-3.82e-03
# M1T2: 2.92e-01+-4.48e-03
# T3: 2.84e-01+-1.05e-02
# T2L1: 2.92e-01+-4.48e-03
# T1L2: 2.77e-01+-2.86e-03
# T1M1L1: 2.49e-01+-2.48e-03
# --------------------------------------
# For S750
# L3: 2.12e-01+-2.19e-03
# M3: 3.55e-01+-6.39e-03
# M2L1: 2.91e-01+-3.08e-03
# M1L2: 2.18e-01+-1.94e-03
# M2T1: 2.98e-01+-3.34e-03
# M1T2: 2.64e-01+-3.90e-03
# T3: 2.40e-01+-8.78e-03
# T2L1: 2.64e-01+-3.90e-03
# T1L2: 2.53e-01+-2.50e-03
# T1M1L1: 2.27e-01+-2.16e-03
# --------------------------------------
# For S800
# L3: 1.88e-01+-1.93e-03
# M3: 3.12e-01+-5.60e-03
# M2L1: 2.64e-01+-2.75e-03
# M1L2: 1.96e-01+-1.72e-03
# M2T1: 2.69e-01+-2.98e-03
# M1T2: 2.35e-01+-3.45e-03
# T3: 1.94e-01+-7.30e-03
# T2L1: 2.35e-01+-3.45e-03
# T1L2: 2.28e-01+-2.22e-03
# T1M1L1: 2.04e-01+-1.93e-03
# --------------------------------------
# For S850
# L3: 1.62e-01+-1.62e-03
# M3: 2.69e-01+-4.74e-03
# M2L1: 2.23e-01+-2.29e-03
# M1L2: 1.68e-01+-1.44e-03
# M2T1: 2.26e-01+-2.47e-03
# M1T2: 1.95e-01+-2.84e-03
# T3: 1.68e-01+-6.19e-03
# T2L1: 1.95e-01+-2.84e-03
# T1L2: 1.94e-01+-1.86e-03
# T1M1L1: 1.75e-01+-1.61e-03
# --------------------------------------
# For S900
# L3: 1.42e-01+-1.41e-03
# M3: 2.30e-01+-4.05e-03
# M2L1: 1.98e-01+-2.01e-03
# M1L2: 1.49e-01+-1.26e-03
# M2T1: 2.00e-01+-2.16e-03
# M1T2: 1.67e-01+-2.44e-03
# T3: 1.37e-01+-5.13e-03
# T2L1: 1.67e-01+-2.44e-03
# T1L2: 1.71e-01+-1.62e-03
# T1M1L1: 1.54e-01+-1.41e-03
# --------------------------------------
# For S950
# L3: 1.21e-01+-1.23e-03
# M3: 1.89e-01+-3.43e-03
# M2L1: 1.65e-01+-1.72e-03
# M1L2: 1.26e-01+-1.09e-03
# M2T1: 1.67e-01+-1.85e-03
# M1T2: 1.38e-01+-2.08e-03
# T3: 1.08e-01+-4.23e-03
# T2L1: 1.38e-01+-2.08e-03
# T1L2: 1.43e-01+-1.39e-03
# T1M1L1: 1.29e-01+-1.21e-03
# --------------------------------------
# For S1000
# L3: 9.69e-02+-1.00e-03
# M3: 1.49e-01+-2.77e-03
# M2L1: 1.31e-01+-1.40e-03
# M1L2: 1.02e-01+-8.96e-04
# M2T1: 1.32e-01+-1.50e-03
# M1T2: 1.08e-01+-1.67e-03
# T3: 8.24e-02+-3.33e-03
# T2L1: 1.08e-01+-1.67e-03
# T1L2: 1.15e-01+-1.14e-03
# T1M1L1: 1.04e-01+-9.92e-04
# --------------------------------------
