# %%
from Generic import *

# %%
Version="/home/jruizalv/V8/"

#Cuts
HTCut = ROOT.TCut("THT>550")
J1PTCut = ROOT.TCut("jet1_pt>150")
L3 = ROOT.TCut("Number_CSVLbtagged_jets>=3")
M3 = ROOT.TCut("Number_CSVMbtagged_jets>=3")
M2L1 = ROOT.TCut("Number_CSVMbtagged_jets>=2 && Number_CSVLbtagged_jets>=1")
M1L2 = ROOT.TCut("Number_CSVMbtagged_jets>=1 && Number_CSVLbtagged_jets>=2")
M2T1 = ROOT.TCut("Number_CSVMbtagged_jets>=2 && Number_CSVTbtagged_jets>=1")
M1T2 = ROOT.TCut("Number_CSVMbtagged_jets>=1 && Number_CSVTbtagged_jets>=2")
T3 = ROOT.TCut("Number_CSVTbtagged_jets>=3")
T2L1 = ROOT.TCut("Number_CSVTbtagged_jets>=2 && Number_CSVLbtagged_jets>=1")
T1L2 = ROOT.TCut("Number_CSVTbtagged_jets>=1 && Number_CSVLbtagged_jets>=2")
T1M1L1 = ROOT.TCut("Number_CSVTbtagged_jets>=1 && Number_CSVMbtagged_jets>=1 && Number_CSVLbtagged_jets>=1")

AllSamples=[]
TotalEntries=[]

for f in files:
    CutsChain=ROOT.TChain("cuts")
    CutsChain.Add(Version+f)
    entries = CutsChain.GetEntries()
    if files.index(f)>=0 and files.index(f)<=NsignalFiles-1: print "Filling signal..."
    elif files.index(f)>0: print "Filling bkgs..."
    print "Entries for file ", f, " are: ", entries
    TempTree= ROOT.TNtuple(ListTreesNamesA[files.index(f)],ListTreesNamesA[files.index(f)],TreeStructure)
    TC=0; L3C=0; M3C=0; M2L1C=0; M1L2C=0; M2T1C=0; M1T2C=0; T3C=0; T2L1C=0; T1L2C=0; T1M1L1C=0
    for i in xrange(entries):
        CutsChain.GetEntry(i)
        if CutsChain.THT<550: continue
        if CutsChain.jet1_pt<150: continue
        TC+=1
        if (CutsChain.Number_CSVLbtagged_jets>=3): L3C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=3): M3C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=2 and CutsChain.Number_CSVLbtagged_jets>=1): M2L1C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=1 and CutsChain.Number_CSVLbtagged_jets>=2): M1L2C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=2 and CutsChain.Number_CSVTbtagged_jets>=1): M2T1C+=1
        if (CutsChain.Number_CSVMbtagged_jets>=1 and CutsChain.Number_CSVTbtagged_jets>=2): M1T2C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=3): T3C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=2 and CutsChain.Number_CSVLbtagged_jets>=1): T2L1C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=1 and CutsChain.Number_CSVLbtagged_jets>=2): T1L2C+=1
        if (CutsChain.Number_CSVTbtagged_jets>=1 and CutsChain.Number_CSVMbtagged_jets>=1 and CutsChain.Number_CSVLbtagged_jets>=1): T1M1L1C+=1
    TotalEntries.append(TC)
    AllSamples.append([L3C, M3C, M2L1C, M1L2C, M2T1C, M1T2C, T3C, T2L1C, T1L2C, T1M1L1C])
# Out:
# Filling signal...
# Entries for file  TpJetM600_5318_Full_analyzed.root  are:  95167
# Filling signal...
# Entries for file  TpJetM650_5318_Full_analyzed.root  are:  98817
# Filling signal...
# Entries for file  TpJetM700_5318_Full_analyzed.root  are:  99464
# Filling signal...
# Entries for file  TpJetM750_5318_Full_analyzed.root  are:  99375
# Filling signal...
# Entries for file  TpJetM800_5318_Full_analyzed.root  are:  95801
# Filling signal...
# Entries for file  TpJetM850_5318_Full_analyzed.root  are:  99257
# Filling signal...
# Entries for file  TpJetM900_5318_Full_analyzed.root  are:  99174
# Filling signal...
# Entries for file  TpJetM950_5318_Full_analyzed.root  are:  95960
# Filling signal...
# Entries for file  TpJetM1000_5318_Full_analyzed.root  are:  99078
# Filling bkgs...
# Entries for file  TTJetsF_5318_Full_analyzed.root  are:  61941200
# Filling bkgs...
# Entries for file  QCD_HT_500_1000_5318_Full_analyzed.root  are:  29019521
# Filling bkgs...
# Entries for file  QCD_HT_1000_Inf_5318_Full_analyzed.root  are:  13438527

# %%
print TotalEntries
print AllSamples
# Out:
# [10187, 12918, 15288, 16713, 16903, 17883, 18441, 17342, 17026, 1735831, 1097972, 1590771]
# [[6428, 3080, 7081, 9004, 6567, 4168, 976, 4168, 7861, 8252], [8260, 3893, 9040, 11414, 8343, 5174, 1178, 5174, 9907, 10436], [9889, 4675, 10696, 13574, 9806, 5935, 1397, 5935, 11661, 12248], [10759, 5042, 11708, 14881, 10630, 6415, 1400, 6415, 12651, 13276], [10734, 4978, 11882, 15027, 10789, 6395, 1283, 6395, 12843, 13468], [11300, 5298, 12287, 15812, 11094, 6506, 1344, 6506, 13351, 14021], [11544, 5198, 12604, 16174, 11363, 6441, 1295, 6441, 13618, 14373], [10811, 4726, 11718, 15193, 10534, 5939, 1137, 5939, 12656, 13359], [10444, 4461, 11165, 14726, 9951, 5562, 1030, 5562, 12190, 12932], [660147, 143984, 790373, 1258455, 703757, 359320, 22052, 359320, 1017486, 1189998], [69891, 5522, 51397, 150699, 40291, 18706, 1018, 18706, 80619, 120366], [107644, 9114, 77546, 235527, 57305, 23123, 1388, 23123, 118270, 178928]]

# %%
#Saving results
FullArray=np.array([TotalEntries, AllSamples])
np.save("3bs_study",FullArray)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-3973f9ebb190> in <module>()
#       1 #Saving results
# ----> 2 FullArray=np.array([TotalEntries, AllSamples])
#       3 np.save("3bs_study",FullArray)
#
# ValueError: setting an array element with a sequence.

# %%
#Reuslts from HT>600, PT(j1)>150
#TotalEntries=[10338, 13617, 16475, 18342, 18823, 20056, 20749, 19698, 19350, 1703495, 1096884, 1646920]
#AllSamples=[[7041, 3306, 7324, 9310, 6767, 4315, 1061, 4315, 8108, 8414], [9329, 4286, 9742, 12235, 8980, 5577, 1301, 5577, 10622, 11071], [11357, 5276, 11772, 14877, 10776, 6571, 1589, 6571, 12807, 13323], [12577, 5783, 13053, 16607, 11875, 7190, 1626, 7190, 14143, 14694], [12749, 5810, 13522, 17010, 12283, 7319, 1505, 7319, 14552, 15139], [13501, 6171, 14019, 17974, 12684, 7453, 1602, 7453, 15225, 15882], [13725, 6101, 14446, 18483, 13008, 7418, 1510, 7418, 15590, 16286], [13097, 5634, 13541, 17533, 12187, 6890, 1341, 6890, 14632, 15311], [12608, 5333, 12931, 17043, 11545, 6455, 1225, 6455, 14127, 14841], [812577, 164162, 821689, 1317838, 730647, 373139, 25382, 373139, 1061994, 1188420], [107986, 6804, 57135, 177276, 44402, 20384, 1232, 20384, 91890, 126078], [170303, 11351, 89348, 285559, 65763, 26569, 1699, 26569, 140230, 194471]]
Cuts=["L3", "M3", "M2L1", "M1L2", "M2T1", "M1T2", "T3", "T2L1", "T1L2", "T1M1L1"]

print "Efficiencies for different 3b's tags selection, HT>550, PT(j1)>150"
print "--------------------------------------"
for i in xrange(len(TotalEntries)):
    print "For", ListTreesNamesA[i].split('n')[0]
    for j in xrange(len(AllSamples[i])):
        print Cuts[j]+":", "{0:.2f}+-{1:.2e}".format(100*float(AllSamples[i][j])/TotalEntries[i],
                                                     100*DivE(float(AllSamples[i][j]),TotalEntries[i],np.sqrt(AllSamples[i][j]),np.sqrt(TotalEntries[i])))
    print "--------------------------------------"
print "--------------------------------------"
print "--------------------------------------"

print "S/B *1000-----------------------------------"
for i in xrange(len(TotalEntries[:NsignalFiles])):
    print "For", ListTreesNamesA[i].split('n')[0]
    for j in xrange(len(AllSamples[i])):
        S=float(AllSamples[i][j]*NWeights[i]); ES=NWeights[i]*np.sqrt(AllSamples[i][j])
        B=((AllSamples[NsignalFiles][j]*TWeight)+(AllSamples[NsignalFiles+1][j]*Q500Weight)+(AllSamples[NsignalFiles+2][j]*Q1000Weight))
        EB=(np.sqrt(AllSamples[NsignalFiles][j])*TWeight)+(np.sqrt(AllSamples[NsignalFiles+1][j])*Q500Weight)+(np.sqrt(AllSamples[NsignalFiles+2][j])*Q1000Weight)
        print Cuts[j]+":", "{0:.2e}+-{1:.2e}".format(1000*S/B,1000*DivE(S,B,ES,EB))
    print "--------------------------------------"
print "--------------------------------------"
print "--------------------------------------"

print "S/sqrt(S+B)*100---------------------------"
for i in xrange(len(TotalEntries[:NsignalFiles])):
    print "For", ListTreesNamesA[i].split('n')[0]
    for j in xrange(len(AllSamples[i])):
        S=float(AllSamples[i][j]*NWeights[i]); ES=NWeights[i]*np.sqrt(AllSamples[i][j])
        B=((AllSamples[NsignalFiles][j]*TWeight)+(AllSamples[NsignalFiles+1][j]*Q500Weight)+(AllSamples[NsignalFiles+2][j]*Q1000Weight))
        EB=(np.sqrt(AllSamples[NsignalFiles][j])*TWeight)+(np.sqrt(AllSamples[NsignalFiles+1][j])*Q500Weight)+(np.sqrt(AllSamples[NsignalFiles+2][j])*Q1000Weight)
        print Cuts[j]+":", "{0:.2e}+-{1:.2e}".format(100*S/np.sqrt(S+B),
                                                     100*DivE(S,np.sqrt(S+B),ES,SqrtE(S+B,ES+EB)))
    print "--------------------------------------"
# Out:
# Efficiencies for different 3b's tags selection, HT>550, PT(j1)>150
# --------------------------------------
# For S600
# L3: 63.10+-1.41e+00
# M3: 30.23+-8.44e-01
# M2L1: 69.51+-1.51e+00
# M1L2: 88.39+-1.81e+00
# M2T1: 64.46+-1.43e+00
# M1T2: 40.91+-1.04e+00
# T3: 9.58+-4.02e-01
# T2L1: 40.91+-1.04e+00
# T1L2: 77.17+-1.63e+00
# T1M1L1: 81.01+-1.69e+00
# --------------------------------------
# For S650
# L3: 63.94+-1.27e+00
# M3: 30.14+-7.48e-01
# M2L1: 69.98+-1.35e+00
# M1L2: 88.36+-1.60e+00
# M2T1: 64.58+-1.28e+00
# M1T2: 40.05+-9.09e-01
# T3: 9.12+-3.46e-01
# T2L1: 40.05+-9.09e-01
# T1L2: 76.69+-1.45e+00
# T1M1L1: 80.79+-1.50e+00
# --------------------------------------
# For S700
# L3: 64.68+-1.17e+00
# M3: 30.58+-6.95e-01
# M2L1: 69.96+-1.24e+00
# M1L2: 88.79+-1.48e+00
# M2T1: 64.14+-1.17e+00
# M1T2: 38.82+-8.18e-01
# T3: 9.14+-3.18e-01
# T2L1: 38.82+-8.18e-01
# T1L2: 76.28+-1.32e+00
# T1M1L1: 80.12+-1.37e+00
# --------------------------------------
# For S750
# L3: 64.38+-1.12e+00
# M3: 30.17+-6.58e-01
# M2L1: 70.05+-1.19e+00
# M1L2: 89.04+-1.42e+00
# M2T1: 63.60+-1.11e+00
# M1T2: 38.38+-7.76e-01
# T3: 8.38+-2.89e-01
# T2L1: 38.38+-7.76e-01
# T1L2: 75.70+-1.26e+00
# T1M1L1: 79.44+-1.30e+00
# --------------------------------------
# For S800
# L3: 63.50+-1.10e+00
# M3: 29.45+-6.44e-01
# M2L1: 70.30+-1.19e+00
# M1L2: 88.90+-1.41e+00
# M2T1: 63.83+-1.11e+00
# M1T2: 37.83+-7.64e-01
# T3: 7.59+-2.70e-01
# T2L1: 37.83+-7.64e-01
# T1L2: 75.98+-1.25e+00
# T1M1L1: 79.68+-1.30e+00
# --------------------------------------
# For S850
# L3: 63.19+-1.07e+00
# M3: 29.63+-6.29e-01
# M2L1: 68.71+-1.13e+00
# M1L2: 88.42+-1.36e+00
# M2T1: 62.04+-1.05e+00
# M1T2: 36.38+-7.23e-01
# T3: 7.52+-2.61e-01
# T2L1: 36.38+-7.23e-01
# T1L2: 74.66+-1.20e+00
# T1M1L1: 78.40+-1.25e+00
# --------------------------------------
# For S900
# L3: 62.60+-1.04e+00
# M3: 28.19+-5.99e-01
# M2L1: 68.35+-1.11e+00
# M1L2: 87.71+-1.34e+00
# M2T1: 61.62+-1.03e+00
# M1T2: 34.93+-6.92e-01
# T3: 7.02+-2.47e-01
# T2L1: 34.93+-6.92e-01
# T1L2: 73.85+-1.18e+00
# T1M1L1: 77.94+-1.22e+00
# --------------------------------------
# For S950
# L3: 62.34+-1.07e+00
# M3: 27.25+-6.03e-01
# M2L1: 67.57+-1.14e+00
# M1L2: 87.61+-1.38e+00
# M2T1: 60.74+-1.05e+00
# M1T2: 34.25+-7.04e-01
# T3: 6.56+-2.44e-01
# T2L1: 34.25+-7.04e-01
# T1L2: 72.98+-1.20e+00
# T1M1L1: 77.03+-1.25e+00
# --------------------------------------
# For S1000
# L3: 61.34+-1.07e+00
# M3: 26.20+-5.93e-01
# M2L1: 65.58+-1.12e+00
# M1L2: 86.49+-1.38e+00
# M2T1: 58.45+-1.03e+00
# M1T2: 32.67+-6.88e-01
# T3: 6.05+-2.35e-01
# T2L1: 32.67+-6.88e-01
# T1L2: 71.60+-1.20e+00
# T1M1L1: 75.95+-1.25e+00
# --------------------------------------
# For T
# L3: 38.03+-7.57e-02
# M3: 8.29+-2.82e-02
# M2L1: 45.53+-8.58e-02
# M1L2: 72.50+-1.20e-01
# M2T1: 40.54+-7.91e-02
# M1T2: 20.70+-5.02e-02
# T3: 1.27+-9.52e-03
# T2L1: 20.70+-5.02e-02
# T1L2: 58.62+-1.03e-01
# T1M1L1: 68.55+-1.15e-01
# --------------------------------------
# For Q500
# L3: 6.37+-3.02e-02
# M3: 0.50+-7.25e-03
# M2L1: 4.68+-2.51e-02
# M1L2: 13.73+-4.85e-02
# M2T1: 3.67+-2.18e-02
# M1T2: 1.70+-1.41e-02
# T3: 0.09+-2.99e-03
# T2L1: 1.70+-1.41e-02
# T1L2: 7.34+-3.29e-02
# T1M1L1: 10.96+-4.21e-02
# --------------------------------------
# For Q1000
# L3: 6.77+-2.60e-02
# M3: 0.57+-6.46e-03
# M2L1: 4.87+-2.14e-02
# M1L2: 14.81+-4.22e-02
# M2T1: 3.60+-1.79e-02
# M1T2: 1.45+-1.07e-02
# T3: 0.09+-2.41e-03
# T2L1: 1.45+-1.07e-02
# T1L2: 7.43+-2.75e-02
# T1M1L1: 11.25+-3.55e-02
# --------------------------------------
# --------------------------------------
# --------------------------------------
# S/B -----------------------------------
# For S600
# L3: 3.64e-01+-5.79e-03
# M3: 1.85e+00+-5.28e-02
# M2L1: 5.11e-01+-8.02e-03
# M1L2: 2.39e-01+-3.09e-03
# M2T1: 5.93e-01+-9.84e-03
# M1T2: 8.02e-01+-1.74e-02
# T3: 3.35e+00+-1.93e-01
# T2L1: 8.02e-01+-1.74e-02
# T1L2: 3.73e-01+-5.38e-03
# T1M1L1: 2.70e-01+-3.69e-03
# --------------------------------------
# For S650
# L3: 3.71e-01+-5.37e-03
# M3: 1.86e+00+-4.94e-02
# M2L1: 5.18e-01+-7.43e-03
# M1L2: 2.41e-01+-2.83e-03
# M2T1: 5.99e-01+-9.10e-03
# M1T2: 7.92e-01+-1.59e-02
# T3: 3.21e+00+-1.76e-01
# T2L1: 7.92e-01+-1.59e-02
# T1L2: 3.74e-01+-4.93e-03
# T1M1L1: 2.72e-01+-3.37e-03
# --------------------------------------
# For S700
# L3: 3.57e-01+-4.82e-03
# M3: 1.79e+00+-4.51e-02
# M2L1: 4.92e-01+-6.64e-03
# M1L2: 2.30e-01+-2.52e-03
# M2T1: 5.65e-01+-8.11e-03
# M1T2: 7.29e-01+-1.39e-02
# T3: 3.06e+00+-1.61e-01
# T2L1: 7.29e-01+-1.39e-02
# T1L2: 3.53e-01+-4.38e-03
# T1M1L1: 2.56e-01+-2.99e-03
# --------------------------------------
# For S750
# L3: 3.21e-01+-4.20e-03
# M3: 1.59e+00+-3.93e-02
# M2L1: 4.45e-01+-5.82e-03
# M1L2: 2.08e-01+-2.20e-03
# M2T1: 5.06e-01+-7.06e-03
# M1T2: 6.51e-01+-1.21e-02
# T3: 2.53e+00+-1.33e-01
# T2L1: 6.51e-01+-1.21e-02
# T1L2: 3.17e-01+-3.81e-03
# T1M1L1: 2.29e-01+-2.59e-03
# --------------------------------------
# For S800
# L3: 2.80e-01+-3.67e-03
# M3: 1.38e+00+-3.41e-02
# M2L1: 3.95e-01+-5.14e-03
# M1L2: 1.84e-01+-1.94e-03
# M2T1: 4.49e-01+-6.23e-03
# M1T2: 5.68e-01+-1.06e-02
# T3: 2.03e+00+-1.09e-01
# T2L1: 5.68e-01+-1.06e-02
# T1L2: 2.81e-01+-3.36e-03
# T1M1L1: 2.03e-01+-2.29e-03
# --------------------------------------
# For S850
# L3: 2.40e-01+-3.09e-03
# M3: 1.19e+00+-2.90e-02
# M2L1: 3.33e-01+-4.27e-03
# M1L2: 1.57e-01+-1.63e-03
# M2T1: 3.76e-01+-5.16e-03
# M1T2: 4.70e-01+-8.71e-03
# T3: 1.73e+00+-9.18e-02
# T2L1: 4.70e-01+-8.71e-03
# T1L2: 2.38e-01+-2.80e-03
# T1M1L1: 1.72e-01+-1.91e-03
# --------------------------------------
# For S900
# L3: 2.11e-01+-2.70e-03
# M3: 1.01e+00+-2.47e-02
# M2L1: 2.94e-01+-3.74e-03
# M1L2: 1.39e-01+-1.42e-03
# M2T1: 3.32e-01+-4.52e-03
# M1T2: 4.01e-01+-7.46e-03
# T3: 1.44e+00+-7.69e-02
# T2L1: 4.01e-01+-7.46e-03
# T1L2: 2.09e-01+-2.45e-03
# T1M1L1: 1.52e-01+-1.67e-03
# --------------------------------------
# For S950
# L3: 1.76e-01+-2.30e-03
# M3: 8.17e-01+-2.05e-02
# M2L1: 2.44e-01+-3.18e-03
# M1L2: 1.16e-01+-1.22e-03
# M2T1: 2.74e-01+-3.84e-03
# M1T2: 3.29e-01+-6.30e-03
# T3: 1.12e+00+-6.23e-02
# T2L1: 3.29e-01+-6.30e-03
# T1L2: 1.73e-01+-2.08e-03
# T1M1L1: 1.26e-01+-1.42e-03
# --------------------------------------
# For S1000
# L3: 1.42e-01+-1.88e-03
# M3: 6.43e-01+-1.64e-02
# M2L1: 1.94e-01+-2.57e-03
# M1L2: 9.39e-02+-9.97e-04
# M2T1: 2.16e-01+-3.08e-03
# M1T2: 2.57e-01+-5.03e-03
# T3: 8.50e-01+-4.83e-02
# T2L1: 2.57e-01+-5.03e-03
# T1L2: 1.39e-01+-1.70e-03
# T1M1L1: 1.02e-01+-1.16e-03
# --------------------------------------
# --------------------------------------
# --------------------------------------
# S/sqrt(S+B)---------------------------
# For S600
# L3: 2.53e+01+-3.59e-01
# M3: 3.94e+01+-9.19e-01
# M2L1: 3.14e+01+-4.34e-01
# M1L2: 2.43e+01+-2.85e-01
# M2T1: 3.26e+01+-4.72e-01
# M1T2: 3.02e+01+-5.61e-01
# T3: 2.99e+01+-1.34e+00
# T2L1: 3.02e+01+-5.61e-01
# T1L2: 2.83e+01+-3.64e-01
# T1M1L1: 2.47e+01+-3.04e-01
# --------------------------------------
# For S650
# L3: 2.58e+01+-3.29e-01
# M3: 3.96e+01+-8.45e-01
# M2L1: 3.19e+01+-3.97e-01
# M1L2: 2.44e+01+-2.58e-01
# M2T1: 3.30e+01+-4.31e-01
# M1T2: 2.98e+01+-5.07e-01
# T3: 2.86e+01+-1.20e+00
# T2L1: 2.98e+01+-5.07e-01
# T1L2: 2.84e+01+-3.30e-01
# T1M1L1: 2.48e+01+-2.76e-01
# --------------------------------------
# For S700
# L3: 2.48e+01+-2.93e-01
# M3: 3.82e+01+-7.61e-01
# M2L1: 3.03e+01+-3.51e-01
# M1L2: 2.33e+01+-2.28e-01
# M2T1: 3.11e+01+-3.80e-01
# M1T2: 2.75e+01+-4.41e-01
# T3: 2.73e+01+-1.08e+00
# T2L1: 2.75e+01+-4.41e-01
# T1L2: 2.68e+01+-2.90e-01
# T1M1L1: 2.34e+01+-2.42e-01
# --------------------------------------
# For S750
# L3: 2.23e+01+-2.54e-01
# M3: 3.40e+01+-6.59e-01
# M2L1: 2.74e+01+-3.06e-01
# M1L2: 2.11e+01+-1.98e-01
# M2T1: 2.79e+01+-3.29e-01
# M1T2: 2.45e+01+-3.82e-01
# T3: 2.26e+01+-8.95e-01
# T2L1: 2.45e+01+-3.82e-01
# T1L2: 2.40e+01+-2.51e-01
# T1M1L1: 2.10e+01+-2.09e-01
# --------------------------------------
# For S800
# L3: 1.95e+01+-2.22e-01
# M3: 2.94e+01+-5.72e-01
# M2L1: 2.43e+01+-2.70e-01
# M1L2: 1.87e+01+-1.75e-01
# M2T1: 2.47e+01+-2.91e-01
# M1T2: 2.14e+01+-3.33e-01
# T3: 1.81e+01+-7.39e-01
# T2L1: 2.14e+01+-3.33e-01
# T1L2: 2.13e+01+-2.22e-01
# T1M1L1: 1.86e+01+-1.85e-01
# --------------------------------------
# For S850
# L3: 1.67e+01+-1.86e-01
# M3: 2.54e+01+-4.84e-01
# M2L1: 2.05e+01+-2.24e-01
# M1L2: 1.60e+01+-1.46e-01
# M2T1: 2.07e+01+-2.40e-01
# M1T2: 1.77e+01+-2.74e-01
# T3: 1.54e+01+-6.20e-01
# T2L1: 1.77e+01+-2.74e-01
# T1L2: 1.81e+01+-1.85e-01
# T1M1L1: 1.57e+01+-1.54e-01
# --------------------------------------
# For S900
# L3: 1.47e+01+-1.62e-01
# M3: 2.15e+01+-4.12e-01
# M2L1: 1.81e+01+-1.96e-01
# M1L2: 1.41e+01+-1.28e-01
# M2T1: 1.83e+01+-2.10e-01
# M1T2: 1.51e+01+-2.35e-01
# T3: 1.28e+01+-5.22e-01
# T2L1: 1.51e+01+-2.35e-01
# T1L2: 1.59e+01+-1.61e-01
# T1M1L1: 1.39e+01+-1.34e-01
# --------------------------------------
# For S950
# L3: 1.23e+01+-1.39e-01
# M3: 1.74e+01+-3.46e-01
# M2L1: 1.50e+01+-1.67e-01
# M1L2: 1.18e+01+-1.10e-01
# M2T1: 1.51e+01+-1.79e-01
# M1T2: 1.24e+01+-1.99e-01
# T3: 1.00e+01+-4.27e-01
# T2L1: 1.24e+01+-1.99e-01
# T1L2: 1.31e+01+-1.37e-01
# T1M1L1: 1.15e+01+-1.15e-01
# --------------------------------------
# For S1000
# L3: 9.87e+00+-1.14e-01
# M3: 1.37e+01+-2.78e-01
# M2L1: 1.19e+01+-1.36e-01
# M1L2: 9.54e+00+-8.99e-02
# M2T1: 1.19e+01+-1.44e-01
# M1T2: 9.70e+00+-1.60e-01
# T3: 7.58e+00+-3.34e-01
# T2L1: 9.70e+00+-1.60e-01
# T1L2: 1.06e+01+-1.12e-01
# T1M1L1: 9.30e+00+-9.40e-02
# --------------------------------------
